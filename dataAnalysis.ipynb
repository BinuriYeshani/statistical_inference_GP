# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="darkgrid")
import seaborn as sns
import re

# %%
data_df = pd.read_csv("data/dataFile.csv", encoding ='UTF-8' ) 

#data_df = pd.read_csv("data/dataFile.csv", encoding ='0D80–0DFF' )  
print(data_df.shape)
print(data_df.sample(5))
# Out:
# (171, 11)
#               Timestamp vote_or_not area_wining_Party          vote_for  \
# 57   10/25/201910:53:21         Yes              SLPP         Gotabhaya
# 120  10/30/201923:11:06         Yes              SLPP         Gotabhaya
# 7    10/24/201923:34:19         Yes              SLPP  MaheshSenanayaka
# 157  10/31/201917:21:50         Yes               UNP   SajithPremadasa
# 119  10/30/201922:44:57          No               UNP   SajithPremadasa
#
#     important_election_question        past_vote_for  \
# 57             NationalSecurity              Mahinda
# 120            NationalSecurity              Mahinda
# 7                    Corruption  MaithripalaSirisena
# 157                CostofLiving  MaithripalaSirisena
# 119                  Corruption  MaithripalaSirisena
#
#     highest_educational_level   age  Gender ethnicity      occupation_sector
# 57     Bachelors'DegreeHolder  1835    Male   Sinhala                Student
# 120    Bachelors'DegreeHolder  1835  Female   Sinhala                Student
# 7      Bachelors'DegreeHolder  1835    Male   Sinhala  PrivateSectorOfficial
# 157             AdvancedLevel  1835  Female    Muslim           SelfEmployed
# 119    Bachelors'DegreeHolder  3660    Male   Sinhala                  Other

# %%
######### remove nan ##########

data_df = data_df.dropna()
print(data_df.shape)
# Out:
# (170, 11)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-8df4e643e761> in <module>
# ----> 1 data_df['vote_or_not'].plot.hist();
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist(self, bins, **kwds)
#    2832         axes : :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#    2833         """
# -> 2834         return self(kind='hist', bins=bins, **kwds)
#    2835
#    2836     @Appender(_kde_docstring % {
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2740                            colormap=colormap, table=table, yerr=yerr,
#    2741                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2742                            **kwds)
#    2743     __call__.__doc__ = plot_series.__doc__
#    2744
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1996                  yerr=yerr, xerr=xerr,
#    1997                  label=label, secondary_y=secondary_y,
# -> 1998                  **kwds)
#    1999
#    2000
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     247     def generate(self):
#     248         self._args_adjust()
# --> 249         self._compute_plot_data()
#     250         self._setup_subplots()
#     251         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     365         if is_empty:
#     366             raise TypeError('Empty {0!r}: no numeric data to '
# --> 367                             'plot'.format(numeric_data.__class__.__name__))
#     368
#     369         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
############ remove question marks in data frame #########################

#data_df=data_df.replace('?','',regex=True).astype(float)

data_df = data_df.replace(['?'], 'A')

print(data_df.sample(5))
# Out:
#               Timestamp vote_or_not area_wining_Party                vote_for  \
# 31    10/25/20199:16:40         Yes              SLPP               Gotabhaya
# 115  10/30/201920:32:52         Yes              SLPP               Gotabhaya
# 63   10/25/201911:45:57         Yes             Other        MaheshSenanayaka
# 101  10/26/201916:27:02         Yes               NPP  AnuraKumaraDissanayaka
# 118  10/30/201922:36:43         Yes              SLPP               Gotabhaya
#
#     important_election_question        past_vote_for  \
# 31             NationalSecurity              Mahinda
# 115            NationalSecurity              Mahinda
# 63                   Corruption              Mahinda
# 101           LackofDevelopment  MaithripalaSirisena
# 118            NationalSecurity              Mahinda
#
#     highest_educational_level   age  Gender ethnicity      occupation_sector
# 31     Bachelors'DegreeHolder  1835  Female   Sinhala     GovernmentOfficial
# 115    Bachelors'DegreeHolder  1835    Male   Sinhala  PrivateSectorOfficial
# 63     Bachelors'DegreeHolder  1835    Male   Sinhala                Student
# 101                     Other  3660    Male   Sinhala  PrivateSectorOfficial
# 118                     Other  1835    Male   Sinhala     GovernmentOfficial

# %%
vote_or_not = data_df.loc[(data_df['vote_or_not'] == 'Yes') | (data_df['vote_or_not'] == 'No')]
vote_or_not_type = vote_or_not.groupby(['vote_or_not', 'vote_for']).size()
vote_or_not_type.unstack().plot(kind='bar', stacked=True)

# %%
genders = data_df.loc[(data_df['Gender'] == 'Male') | (data_df['Gender'] == 'Female')]
gender_type = genders.groupby(['Gender', 'vote_for']).size()
gender_type.unstack().plot(kind='bar', stacked=True)

# %%
ethnicity = data_df.loc[(data_df['ethnicity'] == 'Sinhala') | 
                        (data_df['ethnicity'] == 'Tamil') |
                        (data_df['ethnicity'] == 'Muslim') |
                        (data_df['ethnicity'] == 'Other')] 
ethnicity_type = ethnicity.groupby(['ethnicity', 'vote_for']).size()
ethnicity_type.unstack().plot(kind='bar', stacked=True)

# %%
ethnicity = data_df.loc[(data_df['ethnicity'] == 'Sinhala') | 
                        (data_df['ethnicity'] == 'Tamil') |
                        (data_df['ethnicity'] == 'Muslim') |
                        (data_df['ethnicity'] == 'Other')] 
ethnicity_type = ethnicity.groupby(['ethnicity', 'vote_for']).size()
ethnicity_type.unstack().plot(kind='bar', stacked=True)
